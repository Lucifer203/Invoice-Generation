# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from datasets import load_dataset

ds = load_dataset("katanaml-org/invoices-donut-data-v1")

# %%
schema_dict = {
    "header": {
        "invoice_no": "Invoice number of the document",
        "invoice_date": "Date when the invoice was issued",
        "seller": "Full address and name of the seller",
        "client": "Full address and name of the client",
        "seller_tax_id": "Tax identification number of the seller",
        "client_tax_id": "Tax identification number of the client",
        "iban": "Bank IBAN number of the seller"
    },
    "items": [
        {
            "item_desc": "Description of the service or product sold",
            "item_qty": "Quantity of the item (usually in units or pieces)",
            "item_net_price": "Unit price excluding VAT",
            "item_net_worth": "Total price excluding VAT",
            "item_vat": "VAT rate applied to this item",
            "item_gross_worth": "Total price including VAT"
        }
    ],
    "summary": {
        "total_net_worth": "Total net amount before VAT",
        "total_vat": "Total VAT amount",
        "total_gross_worth": "Final total amount including VAT"
    }
}

# %%
import json
instruction = f"""You are a specialized in invoice and your role is to extract information from any invoice that is provided to you in the following valid json format. if the corresponding value is not present, leave the key with empty string.

{json.dumps(schema_dict)}

Fill the keys only when the information is available.
"""

# %%
instruction
# Out:
# 'You are a specialized in invoice and your role is to extract information from any invoice that is provided to you in the following valid json format. if the corresponding value is not present, leave the key with empty string.\n\n{"header": {"invoice_no": "Invoice number of the document", "invoice_date": "Date when the invoice was issued", "seller": "Full address and name of the seller", "client": "Full address and name of the client", "seller_tax_id": "Tax identification number of the seller", "client_tax_id": "Tax identification number of the client", "iban": "Bank IBAN number of the seller"}, "items": [{"item_desc": "Description of the service or product sold", "item_qty": "Quantity of the item (usually in units or pieces)", "item_net_price": "Unit price excluding VAT", "item_net_worth": "Total price excluding VAT", "item_vat": "VAT rate applied to this item", "item_gross_worth": "Total price including VAT"}], "summary": {"total_net_worth": "Total net amount before VAT", "total_vat": "Total VAT amount", "total_gross_worth": "Final total amount including VAT"}}\n\nFill the keys only when the information is available.\n'

# %%
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("HUGGINGFACE_TOKEN")
login(token=secret_value_0)

# %%
# ! pip install vllm

# %%
import PIL

def create_vllm_messages(image_path,prompt):
    placeholder = "<|image_pad|>"
    vllm_prompt = ("<|im_start|>system\nYou are a helpful assistant.<|im_end|>\n"
          f"<|im_start|>user\n<|vision_start|>{placeholder}<|vision_end|>"
          f"{prompt}<|im_end|>\n"
          "<|im_start|>assistant\n")

    image = PIL.Image.open(image_path)
    inputs = {
        "prompt": vllm_prompt,
        "multi_modal_data": {
            "image": image
        }
    }
    return inputs

# %%
image = ds["test"][2]['image']

# %%
image.save("test_image.png")

# %%
create_vllm_messages("/kaggle/working/test_image.png",instruction)
# Out:
# {'prompt': '<|im_start|>system\nYou are a helpful assistant.<|im_end|>\n<|im_start|>user\n<|vision_start|><|image_pad|><|vision_end|>You are a specialized in invoice and your role is to extract information from any invoice that is provided to you in the following valid json format. if the corresponding value is not present, leave the key with empty string.\n\n{"header": {"invoice_no": "Invoice number of the document", "invoice_date": "Date when the invoice was issued", "seller": "Full address and name of the seller", "client": "Full address and name of the client", "seller_tax_id": "Tax identification number of the seller", "client_tax_id": "Tax identification number of the client", "iban": "Bank IBAN number of the seller"}, "items": [{"item_desc": "Description of the service or product sold", "item_qty": "Quantity of the item (usually in units or pieces)", "item_net_price": "Unit price excluding VAT", "item_net_worth": "Total price excluding VAT", "item_vat": "VAT rate applied to this item", "item_gross_worth": "Total price including VAT"}], "summary": {"total_net_worth": "Total net amount before VAT", "total_vat": "Total VAT amount", "total_gross_worth": "Final total amount including VAT"}}\n\nFill the keys only when the information is available.\n<|im_end|>\n<|im_start|>assistant\n',
#  'multi_modal_data': {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2481x3508>}}

# %%
import os
if not os.path.exists("testing"):
    os.mkdir("testing")

# %%
# Run this in a cell before initializing your model
import torch
torch.cuda.empty_cache()

# %%
! pip install git+https://github.com/huggingface/transformers accelerate
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /tmp/pip-req-build-5eca45jc
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /tmp/pip-req-build-5eca45jc
#   Resolved https://github.com/huggingface/transformers to commit c338fd43b0be2c7f5d73e693fa6fb1b5e7a0bdc2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.54.0.dev0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.54.0.dev0) (0.33.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.54.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.54.0.dev0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.54.0.dev0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.54.0.dev0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.54.0.dev0) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers==4.54.0.dev0) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers==4.54.0.dev0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.54.0.dev0) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (7.0.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate) (2.6.0+cu124)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.54.0.dev0) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.54.0.dev0) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers==4.54.0.dev0) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.54.0.dev0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.54.0.dev0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.54.0.dev0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.54.0.dev0) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.54.0.dev0) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers==4.54.0.dev0) (2.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.54.0.dev0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.54.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.54.0.dev0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.54.0.dev0) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.54.0.dev0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers==4.54.0.dev0) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers==4.54.0.dev0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers==4.54.0.dev0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers==4.54.0.dev0) (2024.2.0)

# %%
! pip install qwen-vl-utils[decord]==0.0.8
# Out:
# Requirement already satisfied: qwen-vl-utils==0.0.8 in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils[decord]==0.0.8) (0.0.8)
# Requirement already satisfied: av in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (15.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (25.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (11.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (2.32.4)
# Requirement already satisfied: decord in /usr/local/lib/python3.11/dist-packages (from qwen-vl-utils[decord]==0.0.8) (0.6.0)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from decord->qwen-vl-utils[decord]==0.0.8) (1.26.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->qwen-vl-utils==0.0.8->qwen-vl-utils[decord]==0.0.8) (2025.6.15)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.14.0->decord->qwen-vl-utils[decord]==0.0.8) (2024.2.0)

# %%
# !nvidia-smi
# Out:
# Tue Jul 22 14:35:41 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# from transformers import Qwen2_5_VLForConditionalGeneration, AutoTokenizer, AutoProcessor
# from transformers import BitsAndBytesConfig

model_id = "Adarsh203/qwen-2.5-vl-3b-invoices"


# model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
#     model_id,
#     device_map="auto")
# processor = AutoProcessor.from_pretrained(model_id)

# %%
from transformers import Qwen2_5_VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from qwen_vl_utils import process_vision_info
# import transformers

# default: Load the model on the available device(s)
model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    model_id, torch_dtype="auto", device_map="auto"
)

# default processer
processor = AutoProcessor.from_pretrained(model_id)
# Out:
# 2025-07-22 14:35:46.434657: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753194946.457045     174 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753194946.463861     174 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.

# %%
import gradio as gr
from PIL import Image
import os
import torch
from transformers import Qwen2_5_VLForConditionalGeneration, AutoProcessor
from qwen_vl_utils import process_vision_info
import json

# Default prompt
instruction = f"""You are a specialized in invoice and your role is to extract information from any invoice that is provided to you in the following valid json format. if the corresponding value is not present, leave the key with empty string.

{json.dumps(schema_dict)}

Fill the keys only when the information is available.
"""

# Function to create messages
def create_messages(image_path, prompt):
    messages = [
        {
            "role": "user",
            "content": [
                {
                    "type": "image",
                    "image": image_path,
                    "resized_height": 640,
                    "resized_width": 640
                },
                {"type": "text", "text": prompt},
            ],
        }
    ]
    return messages

# Inference logic
def infer(messages):
    text = processor.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )
    image_inputs, video_inputs = process_vision_info(messages)
    inputs = processor(
        text=[text],
        images=image_inputs,
        videos=video_inputs,
        padding=True,
        return_tensors="pt",
    )
    inputs = inputs.to(model.device)

    generated_ids = model.generate(**inputs, max_new_tokens=2048)
    generated_ids_trimmed = [
        out_ids[len(in_ids):] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
    ]
    output_text = processor.batch_decode(
        generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
    )
    return output_text[0]

# Gradio handler
def invoice_parser(image: Image.Image):
    image_path = os.path.join("inference", "test_image.png")
    os.makedirs("inference", exist_ok=True)
    image.save(image_path)

    messages = create_messages(image_path=image_path, prompt=instruction)
    output = infer(messages)
    return output

def reset_fields():
    return None, None

# Gradio UI
with gr.Blocks() as demo:
    with gr.Row():
        with gr.Column(scale=1):
            gr.Markdown("### Upload Invoice")
            image_input = gr.Image(type="pil", label="Invoice Image")
            submit_btn = gr.Button("Submit")
            reset_btn = gr.Button("Reset")

        with gr.Column(scale=1):
            gr.Markdown("### Parsed Invoice Details")
            output_text = gr.Textbox(label="Extracted Data", lines=10)

    submit_btn.click(fn=invoice_parser, inputs=image_input, outputs=output_text)
    reset_btn.click(fn=reset_fields, inputs=[], outputs=[image_input, output_text])

demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://febb3627aa01439150.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://febb3627aa01439150.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import os
if not os.path.exists("tests"):
    os.mkdir("tests")

# %%
from tqdm import tqdm

i = 0

ground_truth_list = []
predictions = []
# batched_messages = []

for row in tqdm(ds["test"]):
    image = row['image']
    image_path = os.path.join("tests",f"test_{i}.png")
    image.save(image_path)

    ground_truth = json.loads(row['ground_truth'])["gt_parse"]
    ground_truth_list.append(ground_truth)

    message = create_messages(image_path = image_path,prompt=instruction)
    predict = infer(message)
    predictions.append(predict)
    i+= 1
# Out:
# 100%|██████████| 26/26 [17:28<00:00, 40.31s/it]

# %%
predictions[0]
# Out:
# '{"header": {"invoice_no": "97159829", "invoice_date": "09/18/2015", "seller": "Bradley-Andrade 9879 Elizabeth Common Lake Jonathan, RI 12335", "client": "Castro PLC Unit 9678 Box 9664 DPO AP 69387", "seller_tax_id": "985-73-8194", "client_tax_id": "994-72-1270", "iban": "GB81LLZWO32519172531418"}, "items": [{"item_desc": "12\\" Marble Lapis Inlay Chess Table Top With 2\\" Pieces & 15\\" Wooden Stand W037", "item_qty": "2,00", "item_net_price": "444,60", "item_net_worth": "889,20", "item_vat": "10%", "item_gross_worth": "978,12"}], "summary": {"total_net_worth": "$ 889,20", "total_vat": "$ 88,92", "total_gross_worth": "$ 978,12"}}'

# %%
ground_truth_list[0]
# Out:
# {'header': {'invoice_no': '97159829',
#   'invoice_date': '09/18/2015',
#   'seller': 'Bradley-Andrade 9879 Elizabeth Common Lake Jonathan, RI 12335',
#   'client': 'Castro PLC Unit 9678 Box 9664 DPO AP 69387',
#   'seller_tax_id': '985-73-8194',
#   'client_tax_id': '994-72-1270',
#   'iban': 'GB81LZWO32519172531418'},
#  'items': [{'item_desc': '12" Marble Lapis Inlay Chess Table Top With 2" Pieces & 15" Wooden Stand W537',
#    'item_qty': '2,00',
#    'item_net_price': '444,60',
#    'item_net_worth': '889,20',
#    'item_vat': '10%',
#    'item_gross_worth': '978,12'}],
#  'summary': {'total_net_worth': '$ 889,20',
#   'total_vat': '$ 88,92',
#   'total_gross_worth': '$ 978,12'}}

# %%
import json

def flatten_dict(d, parent_key='', sep=' | '):
    """Flatten a nested dict/list into a readable string format."""
    items = []
    if isinstance(d, dict):
        for k, v in d.items():
            new_key = f"{parent_key}{k}" if parent_key == '' else f"{parent_key}{sep}{k}"
            items.append(flatten_dict(v, new_key, sep=sep))
    elif isinstance(d, list):
        for i, v in enumerate(d):
            new_key = f"{parent_key}[{i}]"
            items.append(flatten_dict(v, new_key, sep=sep))
    else:
        items.append(f"{parent_key}: {d}")
    return sep.join(items)

# Prepare normalized text lists
norm_preds = []
norm_refs = []

for pred_str, gt_dict in zip(predictions, ground_truth_list):
    try:
        pred_dict = json.loads(pred_str)
    except Exception as e:
        print("JSON parse error in prediction:", pred_str)
        pred_dict = {}

    pred_text = flatten_dict(pred_dict)
    gt_text = flatten_dict(gt_dict)

    norm_preds.append(pred_text.lower())
    norm_refs.append(gt_text.lower())

# %%
norm_preds
# Out:
# ['header | invoice_no: 97159829 | header | invoice_date: 09/18/2015 | header | seller: bradley-andrade 9879 elizabeth common lake jonathan, ri 12335 | header | client: castro plc unit 9678 box 9664 dpo ap 69387 | header | seller_tax_id: 985-73-8194 | header | client_tax_id: 994-72-1270 | header | iban: gb81llzwo32519172531418 | items[0] | item_desc: 12" marble lapis inlay chess table top with 2" pieces & 15" wooden stand w037 | items[0] | item_qty: 2,00 | items[0] | item_net_price: 444,60 | items[0] | item_net_worth: 889,20 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 978,12 | summary | total_net_worth: $ 889,20 | summary | total_vat: $ 88,92 | summary | total_gross_worth: $ 978,12',
#  "header | invoice_no: 13194726 | header | invoice_date: 05/29/2021 | header | seller: hopkins and sons 62283 flores tunnel north luis, ia 69983 | header | client: sims plc uss kramer fpo aa 81651 | header | seller_tax_id: 952-73-7223 | header | client_tax_id: 995-88-9495 | header | iban: gb31lzx520242755934691 | items[0] | item_desc: beach lunch lounge striped sue wong dress large navy blue white floral rayon casual | items[0] | item_qty: 1,00 | items[0] | item_net_price: 16,99 | items[0] | item_net_worth: 16,99 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 18,69 | items[1] | item_desc: jams world hawaiian 0 dress rayon sz.l | items[1] | item_qty: 5,00 | items[1] | item_net_price: 65,00 | items[1] | item_net_worth: 325,00 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 357,50 | items[2] | item_desc: lularoe nicole dress size large 26 | items[2] | item_qty: 2,00 | items[2] | item_net_price: 1,99 | items[2] | item_net_worth: 3,98 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 4,38 | items[3] | item_desc: johnny was medium linen wrap dress with rose embroidered bohemian | items[3] | item_qty: 2,00 | items[3] | item_net_price: 89,99 | items[3] | item_net_worth: 179,98 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 197,98 | items[4] | item_desc: eileen fisher women's long sleeve cotton knit straight pocket dress xs gray | items[4] | item_qty: 2,00 | items[4] | item_net_price: 15,99 | items[4] | item_net_worth: 31,98 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 35,18 | items[5] | item_desc: hanna anderson women's l large coral short sleeve casual fall tee shirt dress | items[5] | item_qty: 1,00 | items[5] | item_net_price: 24,00 | items[5] | item_net_worth: 24,00 | items[5] | item_vat: 10% | items[5] | item_gross_worth: 26,40 | summary | total_net_worth: $ 581,93 | summary | total_vat: $ 58,19 | summary | total_gross_worth: $ 640,12",
#  'header | invoice_no: 62517865 | header | invoice_date: 06/02/2015 | header | seller: trujillo-hunt 430 mark ferry suite 495 maxside, dc 65686 | header | client: lee and sons 8552 karen islands east roger, id 40416 | header | seller_tax_id: 992-71-8540 | header | client_tax_id: 929-86-0601 | header | iban: gb73hcph34959888432899 | items[0] | item_desc: care & repair of furniture | items[0] | item_qty: 2,00 | items[0] | item_net_price: 4,25 | items[0] | item_net_worth: 8,50 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 9,35 | summary | total_net_worth: $8,50 | summary | total_vat: $0,85 | summary | total_gross_worth: $9,35',
#  'header | invoice_no: 56014042 | header | invoice_date: 10/01/2014 | header | seller: nichols-barajas 3982 stacy ville apt. 488 lake kristinatown, nd 48049 | header | client: mckay plc 5542 danielle drive suite 381 west mason, me 76671 | header | seller_tax_id: 953-87-6813 | header | client_tax_id: 965-90-8517 | header | iban: gb08kxqt19711661357354 | items[0] | item_desc: jordan hydro 2 (td)-child size 10c | items[0] | item_qty: 2,00 | items[0] | item_net_price: 5,75 | items[0] | item_net_worth: 11,50 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 12,65 | items[1] | item_desc: sketchers energy lights boys black canvas size 4 with charging cable | items[1] | item_qty: 4,00 | items[1] | item_net_price: 12,00 | items[1] | item_net_worth: 48,00 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 52,80 | summary | total_net_worth: $ 59,50 | summary | total_vat: $5,95 | summary | total_gross_worth: $ 65,45',
#  'header | invoice_no: 16662010 | header | invoice_date: 08/28/2016 | header | seller: smith-cook 174 justin causeway west michaelmouth, me 69894 | header | client: snyder-johnson 05173 heather mill jenniferfort, wv 79662 | header | seller_tax_id: 959-84-2124 | header | client_tax_id: 938-85-4960 | header | iban: gb20bakh22085364527355 | items[0] | item_desc: nintendo gameboy pocket console green with box mgb-001 japan tested working | items[0] | item_qty: 1,00 | items[0] | item_net_price: 65,00 | items[0] | item_net_worth: 65,00 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 71,50 | items[1] | item_desc: new sony playstation 4 slim 1tb black name bundle console. sealed! | items[1] | item_qty: 3,00 | items[1] | item_net_price: 399,99 | items[1] | item_net_worth: 1199,97 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 1319,97 | items[2] | item_desc: atari flashback 4 classic game console 75 built in games sports kids family retro! | items[2] | item_qty: 4,00 | items[2] | item_net_price: 8,50 | items[2] | item_net_worth: 34,00 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 37,40 | items[3] | item_desc: sony playstation 1 ps1 console model scph-7501 | items[3] | item_qty: 4,00 | items[3] | item_net_price: 14,99 | items[3] | item_net_worth: 59,96 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 65,96 | items[4] | item_desc: nintendo wii console - 2 remotes w/ covers, nunchucks, setups & games tested working | items[4] | item_qty: 1,00 | items[4] | item_net_price: 85,00 | items[4] | item_net_worth: 85,00 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 93,50 | items[5] | item_desc: sony playstation 3 ps3 super slim black console 20 gb *tested* console & cables | items[5] | item_qty: 4,00 | items[5] | item_net_price: 99,95 | items[5] | item_net_worth: 399,80 | items[5] | item_vat: 10% | items[5] | item_gross_worth: 439,78 | items[6] | item_desc: nintendo gameboy pocket console green with box mgb-001 japan tested working | items[6] | item_qty: 3,00 | items[6] | item_net_price: 70,00 | items[6] | item_net_worth: 210,00 | items[6] | item_vat: 10% | items[6] | item_gross_worth: 231,00 | summary | total_net_worth: $2053,73 | summary | total_vat: $ 205,37 | summary | total_gross_worth: $2259,10',
#  'header | invoice_no: 27543706 | header | invoice_date: 07/20/2020 | header | seller: kaiper, hayes and cook 460 richard forge lake maria, ca 98626 | header | client: holland plc 10833 hill courts suite 606 collinsland, ca 60385 | header | seller_tax_id: 980-78-9083 | header | client_tax_id: 998-85-0115 | header | iban: gb82gocr29918894344551 | items[0] | item_desc: marble beautiful white coffee table top malachite inlay art horton t185372 | items[0] | item_qty: 5,00 | items[0] | item_net_price: 271,01 | items[0] | item_net_worth: 1355,05 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 1 490,55 | items[1] | item_desc: 15"x15" white decorative coffee table top lapis lazuli marquetry patio furniture | items[1] | item_qty: 4,00 | items[1] | item_net_price: 645,77 | items[1] | item_net_worth: 2 583,08 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 2 841,39 | items[2] | item_desc: 16 inches marble coffee table top inlay with multi stone at border game table | items[2] | item_qty: 1,00 | items[2] | item_net_price: 280,50 | items[2] | item_net_worth: 280,50 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 308,55 | items[3] | item_desc: 18" black marble coffee table top inlay floral pietra dura inlay furniture decors h1883b | items[3] | item_qty: 3,00 | items[3] | item_net_price: 377,65 | items[3] | item_net_worth: 1 132,95 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 1 246,24 | items[4] | item_desc: 7\'x4\' pietra dura marble dining hallway table top inlay design patio decor e977a | items[4] | item_qty: 2,00 | items[4] | item_net_price: 19506,53 | items[4] | item_net_worth: 39013,06 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 42914,37 | summary | total_net_worth: $ 44 364,64 | summary | total_vat: $4436,46 | summary | total_gross_worth: $ 48 801,10',
#  'header | invoice_no: 26343874 | header | invoice_date: 07/17/2013 | header | seller: smith ltd 290 jodi gardens charlesview, tn 10958 | header | client: herring-floyd 8113 hansen cliff apt. 826 port alice, id 99663 | header | seller_tax_id: 916-97-6743 | header | client_tax_id: 913-80-4636 | header | iban: gb78tzmx559785640999007 | items[0] | item_desc: microsoft xbox one x 1tb 4k ultra hd console bundle with all the extras great 1787 | items[0] | item_qty: 5,00 | items[0] | item_net_price: 249,00 | items[0] | item_net_worth: 1245,00 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 1369,50 | items[1] | item_desc: cables 500gb.sony playstation 4 ps4 cuh 1215a jet black console controller | items[1] | item_qty: 5,00 | items[1] | item_net_price: 100,00 | items[1] | item_net_worth: 500,00 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 550,00 | items[2] | item_desc: ps2 slim console system scph-77000 pink playstation 2 tested | items[2] | item_qty: 4,00 | items[2] | item_net_price: 252,00 | items[2] | item_net_worth: 1008,00 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 1 108,80 | items[3] | item_desc: nintendo gameboy micro console - black (oxy-f5bb) | items[3] | item_qty: 2,00 | items[3] | item_net_price: 130,00 | items[3] | item_net_worth: 260,00 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 286,00 | items[4] | item_desc: nintendo gamecube system console bundle mario sunshine + genuine controller lot | items[4] | item_qty: 1,00 | items[4] | item_net_price: 159,99 | items[4] | item_net_worth: 159,99 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 175,99 | summary | total_net_worth: $3 172,99 | summary | total_vat: $ 317,30 | summary | total_gross_worth: $3490,29',
#  'header | invoice_no: 12222347 | header | invoice_date: 03/18/2017 | header | seller: gregory, patterson and fischer 439 hunter land south jameschester, mt 09091 | header | client: wilson plc 667 wu ports marshallmouth, ak 03373 | header | seller_tax_id: 958-94-6606 | header | client_tax_id: 928-91-2431 | header | iban: gb10ycp561791374226282 | items[0] | item_desc: zara yellow shift dress xs | items[0] | item_qty: 5,00 | items[0] | item_net_price: 24,75 | items[0] | item_net_worth: 123,75 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 136,13 | summary | total_net_worth: $ 123,75 | summary | total_vat: $ 12,38 | summary | total_gross_worth: $ 136,13',
#  "header | invoice_no: 25698672 | header | invoice_date: 08/01/2015 | header | seller: gordon, alvarado and jones 943 sean park suite 284 north derrick, or 67536 | header | client: manning.ho 92026 michael terrace apt. 138 west michael, il 42693 | header | seller_tax_id: 936-79-2794 | header | client_tax_id: 960-85-1578 | header | iban: gb47jkat88391563723291 | items[0] | item_desc: ccna 200-301 50 gb aug 2020 cisco video/official books/exam dumps/licences | items[0] | item_qty: 5,00 | items[0] | item_net_price: 1,99 | items[0] | item_net_worth: 9,95 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 10,94 | items[1] | item_desc: tales from the buffalo bills | items[1] | item_qty: 5,00 | items[1] | item_net_price: 5,50 | items[1] | item_net_worth: 27,50 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 30,25 | items[2] | item_desc: a boy who grew-up eating nightmare it's okay to not be okay picturebook しんぶんショートストーリー | items[2] | item_qty: 4,00 | items[2] | item_net_price: 19,50 | items[2] | item_net_worth: 78,00 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 85,80 | summary | total_net_worth: $ 115,45 | summary | total_vat: $ 11,55 | summary | total_gross_worth: $ 127,00",
#  'header | invoice_no: 24048799 | header | invoice_date: 05/21/2014 | header | seller: rodriguez-jackson 4804 riley row suite 059 east edwardtown, mn 91106 | header | client: williams, fletcher and taylor 9371 harvey port suite 901 south tabitha, id 50921 | header | seller_tax_id: 983-85-8151 | header | client_tax_id: 932-73-0724 | header | iban: gb85gzih60469560297692 | items[0] | item_desc: large blue long sleeve fit & flare dress elastic waist crochet detail bohemian | items[0] | item_qty: 5,00 | items[0] | item_net_price: 0,99 | items[0] | item_net_worth: 4,95 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 5,45 | summary | total_net_worth: $4,95 | summary | total_vat: $ 0,50 | summary | total_gross_worth: $5,45',
#  'header | invoice_no: 72455228 | header | invoice_date: 05/11/2021 | header | seller: potts, reed and miller uscgcc weeks 26039 anita stravenue fpo aa 06868 | header | client: brady llc north peter, wa 22187 | header | seller_tax_id: 913-82-5781 | header | client_tax_id: 953-75-0545 | header | iban: gb54rdgk5400103726634 | items[0] | item_desc: playstation 5 console disc version "preorder" | items[0] | item_qty: 1,00 | items[0] | item_net_price: 899,99 | items[0] | item_net_worth: 899,99 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 989,99 | items[1] | item_desc: sony playstation4 slim 1tb (upgraded to ssd) black game console | items[1] | item_qty: 2,00 | items[1] | item_net_price: 150,00 | items[1] | item_net_worth: 300,00 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 330,00 | items[2] | item_desc: nintendo gameboy pocket console clear purple with box mgb-001 japan tested 53 | items[2] | item_qty: 1,00 | items[2] | item_net_price: 85,00 | items[2] | item_net_worth: 85,00 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 93,50 | items[3] | item_desc: nec pc engine interface unit ir-1b / hstand / pi-tg001 tested japan | items[3] | item_qty: 1,00 | items[3] | item_net_price: 159,99 | items[3] | item_net_worth: 159,99 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 175,99 | items[4] | item_desc: sony playstation2 slim console set w/ scph-90000 / white "i tested & works" 14a | items[4] | item_qty: 4,00 | items[4] | item_net_price: 90,00 | items[4] | item_net_worth: 360,00 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 396,00 | items[5] | item_desc: magnavox odyssey 2 microprocessor console system w joy sticks & 15 games - 1978 | items[5] | item_qty: 1,00 | items[5] | item_net_price: 155,00 | items[5] | item_net_worth: 155,00 | items[5] | item_vat: 10% | items[5] | item_gross_worth: 170,50 | summary | total_net_worth: $1959,98 | summary | total_vat: $ 196,00 | summary | total_gross_worth: $2155,98',
#  'header | invoice_no: 58478169 | header | invoice_date: 07/04/2016 | header | seller: conley ltd 262 jeffrey underpass jamesview, wa 14945 | header | client: wells-avery 7065 alejandro forks lake jeffrey, me 59849 | header | seller_tax_id: 919-79-8417 | header | client_tax_id: 965-90-7208 | header | iban: gb23mpyi18052629547218 | items[0] | item_desc: 30 inches marble patio table top malachite stone inlaid coffee table 30 inches | items[0] | item_qty: 3,00 | items[0] | item_net_price: 1023,75 | items[0] | item_net_worth: 3071,25 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 3 378,37 | items[1] | item_desc: 48 inch marble restaurant table inlay with lapis lazuli stone dinning table top | items[1] | item_qty: 3,00 | items[1] | item_net_price: 2692,00 | items[1] | item_net_worth: 8076,00 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 8 883,60 | summary | total_net_worth: $ 11 147,25 | summary | total_vat: $1114,73 | summary | total_gross_worth: $ 12 261,98',
#  "header | invoice_no: 90508672 | header | invoice_date: 04/16/2020 | header | seller: stone-waller 53428 peter dale apt, 293 amberchester, ia 57427 | header | client: shaw group 58420 john turnpike suite 767 north ricardo, nv 32611 | header | seller_tax_id: 994-99-6683 | header | client_tax_id: 914-79-8228 | header | iban: gb61gzv246496690777484 | items[0] | item_desc: sofa set | items[0] | item_qty: 2,00 | items[0] | item_net_price: 250,00 | items[0] | item_net_worth: 500,00 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 550,00 | items[1] | item_desc: real madrid inflatable chair (sg16136) | items[1] | item_qty: 3,00 | items[1] | item_net_price: 43,95 | items[1] | item_net_worth: 131,85 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 145,04 | items[2] | item_desc: 13 inch marble coffee table top round table mother of pearl with check pattern | items[2] | item_qty: 4,00 | items[2] | item_net_price: 301,75 | items[2] | item_net_worth: 1207,00 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 1 327,70 | items[3] | item_desc: carnelian stone floral pattern dineet table top marble coffee tables italian art | items[3] | item_qty: 2,00 | items[3] | item_net_price: 993,75 | items[3] | item_net_worth: 1987,50 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 2 186,25 | items[4] | item_desc: 3'x2' black marvels top dining table italian handmade floral art christmas gift | items[4] | item_qty: 1,00 | items[4] | item_net_price: 2585,00 | items[4] | item_net_worth: 2585,00 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 2843,50 | summary | total_net_worth: $6411,35 | summary | total_vat: $ 641,14 | summary | total_gross_worth: $7052,49",
#  'header | invoice_no: 96051364 | header | invoice_date: 04/28/2020 | header | seller: jacobsen ltd 134 catherine valley apt. 756 lake jennifer, ne 09531 | header | client: williams, fowler and phillips 115 mccormick knolls north kevin, tn 27580 | header | seller_tax_id: 914-85-0938 | header | client_tax_id: 963-87-9620 | header | iban: gb61xxnt90578783067262 | items[0] | item_desc: 49"x22" marble top center table carnelian inlay italian art deco christmas gift arts | items[0] | item_qty: 4,00 | items[0] | item_net_price: 2400,00 | items[0] | item_net_worth: 9600,00 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 10 560,00 | items[1] | item_desc: 6\'x3\' marble dining center table with black top floral collectible inlay | items[1] | item_qty: 3,00 | items[1] | item_net_price: 6040,40 | items[1] | item_net_worth: 18 121,20 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 19 933,32 | items[2] | item_desc: 24" blue random marble dining hallway table top lapis lazuli inlay decor e947a | items[2] | item_qty: 5,00 | items[2] | item_net_price: 8194,09 | items[2] | item_net_worth: 40970,45 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 45 067,50 | items[3] | item_desc: 36" marble white top counter table inlay hand pietradura art christmas gifts | items[3] | item_qty: 3,00 | items[3] | item_net_price: 3200,00 | items[3] | item_net_worth: 9600,00 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 10 560,00 | items[4] | item_desc: 6\'x3\' white marble dining table top multi inlay floral elephant art deco home interior | items[4] | item_qty: 5,00 | items[4] | item_net_price: 6408,49 | items[4] | item_net_worth: 32 042,45 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 35 246,69 | items[5] | item_desc: 6\'x3\' marble dining center table marquetry inlay italian mosaic patio arts h3112 | items[5] | item_qty: 5,00 | items[5] | item_net_price: 6647,61 | items[5] | item_net_worth: 33 238,05 | items[5] | item_vat: 10% | items[5] | item_gross_worth: 36 561,85 | summary | total_net_worth: $ 143 572,15 | summary | total_vat: $ 14 357,22 | summary | total_gross_worth: $ 157 929,37',
#  'header | invoice_no: 67856369 | header | invoice_date: 05/27/2020 | header | seller: pierce plc 2454 mcbride ramp apt. 312 new judy, wi 36022 | header | client: cochran-alvarez 448 kenneth mission port caroltown, ny 43776 | header | seller_tax_id: 959-99-4796 | header | client_tax_id: 961-72-7276 | header | iban: gb68kedc47196257123820 | items[0] | item_desc: 24 inches round marble coffee table top inlay sofa table with geometric pattern home decor | items[0] | item_qty: 4,00 | items[0] | item_net_price: 446,25 | items[0] | item_net_worth: 1785,00 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 1963,50 | items[1] | item_desc: 30"x30" marble black top table semi precious bird art black friday gift idea | items[1] | item_qty: 1,00 | items[1] | item_net_price: 2399,00 | items[1] | item_net_worth: 2399,00 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 2638,90 | items[2] | item_desc: 2 inches thick live-edge legs 16" tall cast aluminum cast iron coffee table bench | items[2] | item_qty: 2,00 | items[2] | item_net_price: 159,28 | items[2] | item_net_worth: 318,56 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 350,42 | summary | total_net_worth: $4502,56 | summary | total_vat: $ 450,26 | summary | total_gross_worth: $4952,82',
#  'header | invoice_no: 69934544 | header | invoice_date: 04/17/2014 | header | seller: spence-castro 547 reynolds trafficway suite 938 joshuabury, ri 79742 | header | client: walne and sons 45940 larson stravenue suite 451 port michelle, wi 66283 | header | seller_tax_id: 965-84-3671 | header | client_tax_id: 937-77-3183 | header | iban: gb22mtvu06245364076494 | items[0] | item_desc: hammered brass over stainless steel stemless wine glasses/ candle holders | items[0] | item_qty: 4,00 | items[0] | item_net_price: 9,99 | items[0] | item_net_worth: 39,96 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 43,96 | summary | total_net_worth: $ 39,96 | summary | total_vat: $4,00 | summary | total_gross_worth: $43,96',
#  'header | invoice_no: 23152691 | header | invoice_date: 08/01/2015 | header | seller: whitaker ltd 57724 hall flats apt. 570 robertstonstad, ks 16218 | header | client: stouc-miller 80207 samantha streets suite 926 thomaschester, de 30356 | header | seller_tax_id: 931-73-0965 | header | client_tax_id: 938-72-5881 | header | iban: gb71alpl38952311779111 | items[0] | item_desc: personal computer | items[0] | item_qty: 4,00 | items[0] | item_net_price: 59,00 | items[0] | item_net_worth: 236,00 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 259,60 | items[1] | item_desc: hp all-in-one computer 22" full-hd display intel 2.90ghz 4gb 1tb windows 10 | items[1] | item_qty: 1,00 | items[1] | item_net_price: 449,99 | items[1] | item_net_worth: 449,99 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 494,99 | items[2] | item_desc: dell optiplex sff desktop computer windows 10 4gb 160gb | items[2] | item_qty: 4,00 | items[2] | item_net_price: 89,99 | items[2] | item_net_worth: 359,96 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 395,96 | items[3] | item_desc: hp elite 8300 business usff desktop computer 4gb 250gb windows 10 | items[3] | item_qty: 2,00 | items[3] | item_net_price: 84,99 | items[3] | item_net_worth: 169,98 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 186,98 | items[4] | item_desc: sama rgb gaming pc desktop computer tower intel i5v6 nvidia gtx 1060 16gb windows 10 | items[4] | item_qty: 5,00 | items[4] | item_net_price: 400,00 | items[4] | item_net_worth: 2 000,00 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 2 200,00 | items[5] | item_desc: lenovo c200-all in one desktop computer .with wireless .windows 10 | items[5] | item_qty: 3,00 | items[5] | item_net_price: 277,64 | items[5] | item_net_worth: 832,92 | items[5] | item_vat: 10% | items[5] | item_gross_worth: 916,21 | items[6] | item_desc: dell optiplex 7040 sff pc computer intel core i5-6500 3.2ghz 4gb ram 500gb hdd | items[6] | item_qty: 3,00 | items[6] | item_net_price: 99,99 | items[6] | item_net_worth: 299,97 | items[6] | item_vat: 10% | items[6] | item_gross_worth: 329,97 | summary | total_net_worth: $4348,82 | summary | total_vat: $ 434,88 | summary | total_gross_worth: $4783,70',
#  "header | invoice_no: 14878236 | header | invoice_date: 04/26/2015 | header | seller: hernandez, coleman and alvarado 6080 justin fort suite 152 brownburgh, nc 87582 | header | client: turner-green 7245 stephens orchard lake mitchellview, mi 50388 | header | seller_tax_id: 988-79-4495 | header | client_tax_id: 950-70-5065 | header | iban: gb81vwarz09653710676977 | items[0] | item_desc: cabi 5610 striped white blue launch maxi dress womens sz m | items[0] | item_qty: 3,00 | items[0] | item_net_price: 48,99 | items[0] | item_net_worth: 146,97 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 161,67 | items[1] | item_desc: boden black blue floral short sleeve dress size 6 | items[1] | item_qty: 2,00 | items[1] | item_net_price: 36,99 | items[1] | item_net_worth: 73,98 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 81,38 | items[2] | item_desc: ann taylor loft 3/4 knit sleeve dress size 0 | items[2] | item_qty: 4,00 | items[2] | item_net_price: 8,00 | items[2] | item_net_worth: 32,00 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 35,20 | items[3] | item_desc: divided black asymmetrical duster jacket | items[3] | item_qty: 2,00 | items[3] | item_net_price: 7,99 | items[3] | item_net_worth: 15,98 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 17,58 | items[4] | item_desc: women elegant fashion o-neck knee length short sleeve retro floral print dress | items[4] | item_qty: 4,00 | items[4] | item_net_price: 12,00 | items[4] | item_net_worth: 48,00 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 52,80 | items[5] | item_desc: vintage bohemian francisa plus size dress 22w floral cottagecore | items[5] | item_qty: 3,00 | items[5] | item_net_price: 49,96 | items[5] | item_net_worth: 149,88 | items[5] | item_vat: 10% | items[5] | item_gross_worth: 164,87 | items[6] | item_desc: matilda jane women's light rising high low green floral dress size l pockets | items[6] | item_qty: 1,00 | items[6] | item_net_price: 50,00 | items[6] | item_net_worth: 50,00 | items[6] | item_vat: 10% | items[6] | item_gross_worth: 55,00 | summary | total_net_worth: $ 516,81 | summary | total_vat: $ 51,68 | summary | total_gross_worth: $ 568,49",
#  'header | invoice_no: 84777898 | header | invoice_date: 06/02/2017 | header | seller: byrd plc 5954 stewart isle suite 748 south sarahshire, dc 77638 | header | client: palmer llc 221 sarah forge north elizabeth, ky 13557 | header | seller_tax_id: 991-72-8541 | header | client_tax_id: 947-73-4805 | header | iban: gb55nfwy80188862802477 | items[0] | item_desc: vintage cobalt blue spiral stemmed wine glasses - pair | items[0] | item_qty: 1,00 | items[0] | item_net_price: 30,00 | items[0] | item_net_worth: 30,00 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 33,00 | items[1] | item_desc: 1pc tricycle shape red wine bottle rack bar cup holder display rack for home bar kitchen | items[1] | item_qty: 5,00 | items[1] | item_net_price: 32,13 | items[1] | item_net_worth: 160,65 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 176,72 | items[2] | item_desc: wine glass european style wine glass rack for home kitchen bar furniture decor | items[2] | item_qty: 3,00 | items[2] | item_net_price: 31,79 | items[2] | item_net_worth: 95,37 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 104,91 | summary | total_net_worth: $ 286,02 | summary | total_vat: $ 28,60 | summary | total_gross_worth: $ 314,62',
#  'header | invoice_no: 57338979 | header | invoice_date: 05/10/2021 | header | seller: estrada and sons 70379 brooks heights apt. 110 lake megan, wi 84417 | header | client: santana-sherman 4195 sutton plaza suite 750 christopherfort, ms 70499 | header | seller_tax_id: 926-74-0874 | header | client_tax_id: 939-81-4695 | header | iban: gb90alyu92362601688809 | items[0] | item_desc: 3\'x2\' black marvels top dining table italian handmade floral art deco furniture w354 | items[0] | item_qty: 5,00 | items[0] | item_net_price: 2585,00 | items[0] | item_net_worth: 12925,00 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 14 217,50 | items[1] | item_desc: 12" marble coffee table top multi stone peacock & floral inlay home decors w364 | items[1] | item_qty: 3,00 | items[1] | item_net_price: 264,27 | items[1] | item_net_worth: 792,81 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 872,09 | summary | total_net_worth: $ 13 717,81 | summary | total_vat: $1371,78 | summary | total_gross_worth: $ 15 089,59',
#  'header | invoice_no: 54394190 | header | invoice_date: 02/23/2021 | header | seller: neilson, bird and mendoza 48426 john village suite 517 boydstad, id 55416 | header | client: allen inc uss smith fpo ap 40020 | header | seller_tax_id: 976-76-5964 | header | client_tax_id: 925-90-1124 | header | iban: gb83gdhn20059173458044 | items[0] | item_desc: microsoft xbox one s 1tb console system model 1681 w/ one controller & cables | items[0] | item_qty: 1,00 | items[0] | item_net_price: 219,99 | items[0] | item_net_worth: 219,99 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 241,99 | items[1] | item_desc: nintendo 64 n64 console complete in box mint beautiful!! from japan! | items[1] | item_qty: 1,00 | items[1] | item_net_price: 269,99 | items[1] | item_net_worth: 269,99 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 296,99 | items[2] | item_desc: playstation new sony playstation 5 console disk version ships fast 11/12 confirmed | items[2] | item_qty: 3,00 | items[2] | item_net_price: 850,00 | items[2] | item_net_worth: 2550,00 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 2805,00 | items[3] | item_desc: sony scph-30001r playstation 2 console game system w/ network adapter | items[3] | item_qty: 4,00 | items[3] | item_net_price: 79,99 | items[3] | item_net_worth: 319,96 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 351,96 | summary | total_net_worth: $3359,94 | summary | total_vat: $335,99 | summary | total_gross_worth: $3695,93',
#  'header | invoice_no: 77404624 | header | invoice_date: 10/20/2014 | header | seller: hayes-mcdonald 6220 hughes isle east charlesmouth, nm 82727 | header | client: sheppard, guerrero and castillo 8846 bryan turnpike wallaceborough, wi 93615 | header | seller_tax_id: 906-99-8086 | header | client_tax_id: 960-84-4731 | header | iban: gb91dido06197597108680 | items[0] | item_desc: hp desktop computer 400 g1 core i5-16gb ram 1tb hdd 256gb ssd 19" lcd windows 10 pc | items[0] | item_qty: 2,00 | items[0] | item_net_price: 139,95 | items[0] | item_net_worth: 279,90 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 307,89 | items[1] | item_desc: lenovo c200...all in one desktop computer ..with wireless keyboard.. | items[1] | item_qty: 5,00 | items[1] | item_net_price: 277,64 | items[1] | item_net_worth: 1388,20 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 1527,02 | items[2] | item_desc: amd quad core custom built gaming pc computer desktop 16gb 2tb blue led | items[2] | item_qty: 4,00 | items[2] | item_net_price: 509,99 | items[2] | item_net_worth: 2039,96 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 2243,96 | items[3] | item_desc: custom built blue ryzen 7 2700g 32gb ram, computer , 32 gb ram, | items[3] | item_qty: 3,00 | items[3] | item_net_price: 1400,00 | items[3] | item_net_worth: 4200,00 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 4 620,00 | items[4] | item_desc: dell desktop computer optiplex 790 tower pc core i5 8gb 500gb windows 10 pro | items[4] | item_qty: 5,00 | items[4] | item_net_price: 149,95 | items[4] | item_net_worth: 749,75 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 824,73 | items[5] | item_desc: intel compute stick pc (32gb) 1.0ghz, 2gb - boxstickiazwnfc + wireless keyboard | items[5] | item_qty: 1,00 | items[5] | item_net_price: 29,99 | items[5] | item_net_worth: 29,99 | items[5] | item_vat: 10% | items[5] | item_gross_worth: 32,99 | summary | total_net_worth: $8687,80 | summary | total_vat: $868,78 | summary | total_gross_worth: $9556,58',
#  'header | invoice_no: 32830026 | header | invoice_date: 12/20/2014 | header | seller: george, casey and harris 0943 justin branch apt. 233 ingramberg, de 59102 | header | client: stewart, fields and scott 07095 robert cape marquezburgh, dc 81706 | header | seller_tax_id: 907-77-8965 | header | client_tax_id: 995-83-6792 | header | iban: gb81ouzn44807763808287 | items[0] | item_desc: sony playstation2 console scph-39000 white pearl color / tested 11174 | items[0] | item_qty: 5,00 | items[0] | item_net_price: 45,00 | items[0] | item_net_worth: 225,00 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 247,50 | items[1] | item_desc: nintendo switch lite gray console only no accessories or charger [b5-2] | items[1] | item_qty: 1,00 | items[1] | item_net_price: 135,00 | items[1] | item_net_worth: 135,00 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 148,50 | items[2] | item_desc: nintendo wii console rvl-001 complete hookups w/ mario&sonic; tested / working | items[2] | item_qty: 3,00 | items[2] | item_net_price: 78,88 | items[2] | item_net_worth: 236,64 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 260,30 | items[3] | item_desc: b351 nintendo new 3ds console white japan w/stylus pen | items[3] | item_qty: 4,00 | items[3] | item_net_price: 79,99 | items[3] | item_net_worth: 319,96 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 351,96 | items[4] | item_desc: sony saturn console gray hst-3200 hst-3210 japanese | items[4] | item_qty: 1,00 | items[4] | item_net_price: 119,98 | items[4] | item_net_worth: 119,98 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 131,98 | summary | total_net_worth: $1036,58 | summary | total_vat: $ 103,66 | summary | total_gross_worth: $1140,24',
#  'header | invoice_no: 71748307 | header | invoice_date: 12/24/2011 | header | seller: velasquez2, ward and ballard 87336 payne way suite 716 parkerton, fl 76330 | header | client: lewis group 537 wilson parkways north mary, al 69775 | header | seller_tax_id: 950-74-4484 | header | client_tax_id: 996-86-8087 | header | iban: gb48eapq46997886926034 | items[0] | item_desc: 2pcs baby boys clothes cotton hooded top+pants baby boys outfit spring summer | items[0] | item_qty: 5,00 | items[0] | item_net_price: 10,99 | items[0] | item_net_worth: 54,95 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 60,45 | items[1] | item_desc: fire los angeles dress medium | items[1] | item_qty: 2,00 | items[1] | item_net_price: 6,50 | items[1] | item_net_worth: 13,00 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 14,30 | items[2] | item_desc: pas de calaie dress womens size 36 | items[2] | item_qty: 3,00 | items[2] | item_net_price: 9,95 | items[2] | item_net_worth: 29,85 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 32,83 | items[3] | item_desc: zara yellow shift dress xs | items[3] | item_qty: 5,00 | items[3] | item_net_price: 24,75 | items[3] | item_net_worth: 123,75 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 136,13 | items[4] | item_desc: miley cyrus bubble dress | items[4] | item_qty: 2,00 | items[4] | item_net_price: 16,00 | items[4] | item_net_worth: 32,00 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 35,20 | items[5] | item_desc: nwt $1200 j.crew silk chiffon ivory wedding dress with beading | items[5] | item_qty: 4,00 | items[5] | item_net_price: 295,00 | items[5] | item_net_worth: 1180,00 | items[5] | item_vat: 10% | items[5] | item_gross_worth: 1 298,00 | summary | total_net_worth: $1433,55 | summary | total_vat: $ 143,35 | summary | total_gross_worth: $1576,90',
#  'header | invoice_no: 17619666 | header | invoice_date: 03/09/2020 | header | seller: wilkererson ltd 49006 saunders villages suite 098 north jennifer, tn 83320 | header | client: english-brown 56684 tracey ranch north gabrielle, sc 15965 | header | seller_tax_id: 941-97-9699 | header | client_tax_id: 937-79-7558 | header | iban: gb40jkgk45011938135603 | items[0] | item_desc: used couch dark blue | items[0] | item_qty: 2,00 | items[0] | item_net_price: 97,00 | items[0] | item_net_worth: 194,00 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 213,40 | items[1] | item_desc: blue shiny stone floral art dinning table top marble kitchen table furniture decors | items[1] | item_qty: 3,00 | items[1] | item_net_price: 3960,00 | items[1] | item_net_worth: 11880,00 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 13 068,00 | items[2] | item_desc: 24" sale online coffee top table marquetry inlay floral design christmas gift | items[2] | item_qty: 5,00 | items[2] | item_net_price: 1188,00 | items[2] | item_net_worth: 5940,00 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 6534,00 | items[3] | item_desc: 34"x34" marble round top counter table lapis floral inlaid art christmas gifts | items[3] | item_qty: 3,00 | items[3] | item_net_price: 1900,00 | items[3] | item_net_worth: 5 700,00 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 6 270,00 | items[4] | item_desc: 35" round marble coffee top table lapis floral inlay home decor furniture decors b430 | items[4] | item_qty: 4,00 | items[4] | item_net_price: 1259,00 | items[4] | item_net_worth: 5036,00 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 5539,60 | items[5] | item_desc: 54 inches marble dinning table top hand crafted reception table home furniture | items[5] | item_qty: 2,00 | items[5] | item_net_price: 4452,00 | items[5] | item_net_worth: 8904,00 | items[5] | item_vat: 10% | items[5] | item_gross_worth: 9 794,40 | summary | total_net_worth: $ 37 654,00 | summary | total_vat: $3765,40 | summary | total_gross_worth: $41419,40',
#  'header | invoice_no: 12681565 | header | invoice_date: 09/07/2015 | header | seller: clay-koch 2467 john knolls apt. 099 markside, mt 79068 | header | client: thompson-baker usnv kennedy fpo aa 01185 | header | seller_tax_id: 915-72-3800 | header | client_tax_id: 971-96-6933 | header | iban: gb20ifbt89821062114124 | items[0] | item_desc: n64 nintendo system console lite bundle with controller tested working | items[0] | item_qty: 5,00 | items[0] | item_net_price: 95,99 | items[0] | item_net_worth: 479,95 | items[0] | item_vat: 10% | items[0] | item_gross_worth: 527,95 | items[1] | item_desc: original nintendo gaming console with robot, 9 games & extras | items[1] | item_qty: 5,00 | items[1] | item_net_price: 475,00 | items[1] | item_net_worth: 2375,00 | items[1] | item_vat: 10% | items[1] | item_gross_worth: 2 612,50 | items[2] | item_desc: nintendo blue wii system game console complete with 2 motion remotes tested work | items[2] | item_qty: 2,00 | items[2] | item_net_price: 99,98 | items[2] | item_net_worth: 199,96 | items[2] | item_vat: 10% | items[2] | item_gross_worth: 219,96 | items[3] | item_desc: nintendo gameboy pocket console green with box mgb-001 japan tested 53 | items[3] | item_qty: 4,00 | items[3] | item_net_price: 85,00 | items[3] | item_net_worth: 340,00 | items[3] | item_vat: 10% | items[3] | item_gross_worth: 374,00 | items[4] | item_desc: playstation 2 slim console white scph-90000 boxed japan ps2 system | items[4] | item_qty: 3,00 | items[4] | item_net_price: 199,00 | items[4] | item_net_worth: 597,00 | items[4] | item_vat: 10% | items[4] | item_gross_worth: 656,70 | summary | total_net_worth: $3991,91 | summary | total_vat: $ 399,19 | summary | total_gross_worth: $4391,10']

# %%
# !pip install evaluate rouge-score
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting evaluate
#   Downloading evaluate-0.4.5-py3-none-any.whl.metadata (9.5 kB)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.5.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.33.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (19.0.1)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.12.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->evaluate) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.6.15)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->evaluate) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->evaluate) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->evaluate) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->evaluate) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->evaluate) (2024.2.0)
# Downloading evaluate-0.4.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 6.5 MB/s eta 0:00:00
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=f622bb2b965ab9d40611f14029e9a1e396b90e5f23928a14f1271965bc87df96
#   Stored in directory: /root/.cache/pip/wheels/1e/19/43/8a442dc83660ca25e163e1bd1f89919284ab0d0c1475475148
# Successfully built rouge-score
# Installing collected packages: fsspec, rouge-score, evaluate
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.5.1
#     Uninstalling fsspec-2025.5.1:
#       Successfully uninstalled fsspec-2025.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# Successfully installed evaluate-0.4.5 fsspec-2025.3.0 rouge-score-0.1.2

# %% [markdown]
# #### Model Evaluation

# %%
import evaluate

rouge = evaluate.load("rouge")
results = rouge.compute(predictions=norm_preds, references=norm_refs)
print(results)
# Out:
# Downloading builder script: 0.00B [00:00, ?B/s]
# {'rouge1': 0.9717973759033505, 'rouge2': 0.9517742369542243, 'rougeL': 0.9705970469093224, 'rougeLsum': 0.9705499501599857}

# %%
from collections import Counter

def flatten_dict(d,parent_keys=""):
    items = {}
    for k,v in d.items():
        new_key = f"{parent_key}.{k}" if parent_key else k

        if isinstance(v,dict):
            items.update(flatten_dict(v,new_key))
        elif isinstance(v,list):
            if all(isinstance(i,dict) for i in v):
                for idx,item in enumerate(v):
                    items.update(flatten_dict(item,f"{new_key}[{idx}]"))
            else:
                items[new_key] = v
        else:
            items[new_key] = v
    return items

# %%
with open("predictions.txt",'w') as file:
    for item in predictions:
        file.write(str(item) + '\n')

# %%
import json, ast, re
from decimal import Decimal, InvalidOperation
from collections import defaultdict


def parse_pred(pred_str):
    """Robust JSON parse. Fall back to ast.literal_eval; return {} on failure."""
    if isinstance(pred_str, dict):
        return pred_str
    try:
        return json.loads(pred_str)
    except Exception:
        try:
            return ast.literal_eval(pred_str)
        except Exception:
            return {}


_ws_re = re.compile(r"\s+")

def norm_text(x):
    if x is None:
        return ""
    s = str(x)
    s = s.replace('\\"', '"')  # unescape quotes
    s = _ws_re.sub(" ", s).strip().lower()
    return s

_currency_re = re.compile(r"[^\d,.\-]")

def norm_number(x):
    """Return canonical numeric string, or raw normalized text if cannot parse."""
    if x is None:
        return ""
    s = str(x)
    s = s.strip()
    s = _currency_re.sub("", s)
    if s.count(",") == 1 and s.count(".") == 0:
        s = s.replace(",", ".")

    if s.count(".") > 1:
        parts = s.split(".")
        s = "".join(parts[:-1]) + "." + parts[-1]
    try:
        val = Decimal(s)
   
        quant = Decimal("0.0001")
        valq = val.quantize(quant) if val.as_tuple().exponent < -4 else val
        return str(valq.normalize())
    except (InvalidOperation, ValueError):
        return norm_text(x)

NUMERIC_FIELD_FRAGMENTS = {
    "qty", "price", "worth", "vat", "total", "amount", "gross", "net"
}

def is_numeric_key(flat_key):
    lk = flat_key.lower()
    return any(seg in lk for seg in NUMERIC_FIELD_FRAGMENTS)

def normalize_value(flat_key, value):
    return norm_number(value) if is_numeric_key(flat_key) else norm_text(value)


def flatten(obj, prefix=""):
    """
    Returns dict: flat_key -> value (leaf scalars only).
    Lists indexed as [i]; nested dicts dotted.
    """
    flat = {}
    if isinstance(obj, dict):
        for k, v in obj.items():
            new_pref = f"{prefix}.{k}" if prefix else k
            flat.update(flatten(v, new_pref))
    elif isinstance(obj, list):
        for i, v in enumerate(obj):
            new_pref = f"{prefix}[{i}]"
            flat.update(flatten(v, new_pref))
    else:
        flat[prefix] = obj
    return flat


def evaluate_structured_predictions(predictions, ground_truth_list, return_per_example=True):
    """
    predictions: list[str|dict]
    ground_truth_list: list[dict]
    """
    assert len(predictions) == len(ground_truth_list), "Length mismatch."

    per_example = []
    field_totals = defaultdict(int)
    field_correct = defaultdict(int)
    n_examples = len(predictions)
    parse_failures = 0

    for idx, (pred_raw, gt_dict) in enumerate(zip(predictions, ground_truth_list)):
        pred_dict = parse_pred(pred_raw)
        if not pred_dict:
            parse_failures += 1

        flat_gt = flatten(gt_dict)
        flat_pr = flatten(pred_dict)

        ex_record = {"index": idx, "num_fields": 0, "num_correct": 0, "errors": []}

        for k_gt, v_gt in flat_gt.items():
            field_totals[k_gt] += 1
            ex_record["num_fields"] += 1

            v_pr = flat_pr.get(k_gt, None)

            norm_gt = normalize_value(k_gt, v_gt)
            norm_pr = normalize_value(k_gt, v_pr)

            if norm_pr == norm_gt:
                field_correct[k_gt] += 1
                ex_record["num_correct"] += 1
            else:
                ex_record["errors"].append({
                    "field": k_gt,
                    "gt": v_gt,
                    "pred": v_pr,
                    "norm_gt": norm_gt,
                    "norm_pred": norm_pr
                })

        per_example.append(ex_record)

    # Per-field accuracy
    field_accuracy = {
        k: field_correct[k] / field_totals[k] for k in field_totals
    }

    # Macro accuracy: mean over fields
    macro_acc = sum(field_accuracy.values()) / len(field_accuracy) if field_accuracy else 0.0

    # Micro accuracy: all correct fields / all fields
    total_correct = sum(field_correct.values())
    total_fields = sum(field_totals.values())
    micro_acc = total_correct / total_fields if total_fields else 0.0

    report = {
        "n_examples": n_examples,
        "parse_failures": parse_failures,
        "micro_accuracy": micro_acc,
        "macro_accuracy": macro_acc,
        "field_accuracy": dict(sorted(field_accuracy.items())),
    }

    if return_per_example:
        return report, per_example
    return report


def print_field_report(report, top_n=None):
    print(f"Examples: {report['n_examples']}")
    print(f"Prediction parse failures: {report['parse_failures']}")
    print(f"Micro accuracy: {report['micro_accuracy']:.4f}")
    print(f"Macro accuracy: {report['macro_accuracy']:.4f}")
    print("\nPer-field accuracy:")
    items = list(report["field_accuracy"].items())
    if top_n is not None:
        items = items[:top_n]
    for k, v in items:
        print(f"  {k:<40} {v:.4f}")

# %%
report, per_ex = evaluate_structured_predictions(predictions, ground_truth_list)
print_field_report(report)

# Inspect a specific example with errors
i = 0
print("\nErrors for example", i, ":")
for err in per_ex[i]["errors"]:
    print(f"- {err['field']}: GT={err['gt']} | PRED={err['pred']}")
# Out:
# Examples: 26
# Prediction parse failures: 0
# Micro accuracy: 0.8939
# Macro accuracy: 0.8606
#
# Per-field accuracy:
#   header.client                            0.7308
#   header.client_tax_id                     1.0000
#   header.iban                              0.5000
#   header.invoice_date                      1.0000
#   header.invoice_no                        1.0000
#   header.seller                            0.5769
#   header.seller_tax_id                     1.0000
#   items[0].iban                            0.0000
#   items[0].item_desc                       0.3462
#   items[0].item_gross_worth                1.0000
#   items[0].item_net_price                  1.0000
#   items[0].item_net_worth                  1.0000
#   items[0].item_qty                        1.0000
#   items[0].item_vat                        1.0000
#   items[1].iban                            0.0000
#   items[1].item_desc                       0.4762
#   items[1].item_gross_worth                1.0000
#   items[1].item_net_price                  1.0000
#   items[1].item_net_worth                  1.0000
#   items[1].item_qty                        1.0000
#   items[1].item_vat                        1.0000
#   items[2].item_desc                       0.5556
#   items[2].item_gross_worth                1.0000
#   items[2].item_net_price                  1.0000
#   items[2].item_net_worth                  1.0000
#   items[2].item_qty                        1.0000
#   items[2].item_vat                        1.0000
#   items[3].item_desc                       0.2000
#   items[3].item_gross_worth                1.0000
#   items[3].item_net_price                  1.0000
#   items[3].item_net_worth                  1.0000
#   items[3].item_qty                        1.0000
#   items[3].item_vat                        1.0000
#   items[4].item_desc                       0.4286
#   items[4].item_gross_worth                1.0000
#   items[4].item_net_price                  1.0000
#   items[4].item_net_worth                  1.0000
#   items[4].item_qty                        1.0000
#   items[4].item_vat                        1.0000
#   items[5].item_desc                       0.5556
#   items[5].item_gross_worth                1.0000
#   items[5].item_net_price                  1.0000
#   items[5].item_net_worth                  1.0000
#   items[5].item_qty                        1.0000
#   items[5].item_vat                        1.0000
#   items[5].total_net_worth                 0.0000
#   items[6].item_desc                       1.0000
#   items[6].item_gross_worth                1.0000
#   items[6].item_net_price                  1.0000
#   items[6].item_net_worth                  1.0000
#   items[6].item_qty                        1.0000
#   items[6].item_vat                        1.0000
#   summary.total_gross_worth                0.9615
#   summary.total_net_worth                  1.0000
#   summary.total_vat                        1.0000
#
# Errors for example 0 :
# - header.iban: GT=GB81LZWO32519172531418 | PRED=GB81LLZWO32519172531418
# - items[0].item_desc: GT=12" Marble Lapis Inlay Chess Table Top With 2" Pieces & 15" Wooden Stand W537 | PRED=12" Marble Lapis Inlay Chess Table Top With 2" Pieces & 15" Wooden Stand W037
